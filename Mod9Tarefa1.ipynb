# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...         5.0
# 1      8 a 11 anos    999992.0         1.0         0.0  ...         5.0
# 2      8 a 11 anos    513205.0         2.0         0.0  ...         5.0
# 3  12 anos ou mais    231205.0         0.0         0.0  ...         4.0
# 4      8 a 11 anos    999992.0         1.0         0.0  ...         5.0
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0      1.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1      2.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2      3.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3      4.0        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4      5.0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
print('Quantidade de linhas duplicadas:',
      sinasc_raw.duplicated().sum())
# Out:
# Quantidade de linhas duplicadas: 0

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16064 entries, 0 to 16063
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        16064 non-null  int64
#  1   CODESTAB      15999 non-null  float64
#  2   CODMUNNASC    16064 non-null  int64
#  3   LOCNASC       16064 non-null  int64
#  4   IDADEMAE      16064 non-null  int64
#  5   ESTCIVMAE     15883 non-null  float64
#  6   ESCMAE        15900 non-null  object
#  7   CODOCUPMAE    14596 non-null  float64
#  8   QTDFILVIVO    15158 non-null  float64
#  9   QTDFILMORT    14857 non-null  float64
#  10  CODMUNRES     16064 non-null  int64
#  11  GESTACAO      15414 non-null  object
#  12  GRAVIDEZ      16024 non-null  object
#  13  PARTO         16041 non-null  object
#  14  CONSULTAS     16064 non-null  int64
#  15  DTNASC        16064 non-null  object
#  16  HORANASC      16055 non-null  float64
#  17  SEXO          16060 non-null  object
#  18  APGAR1        16016 non-null  float64
#  19  APGAR5        16010 non-null  float64
#  20  RACACOR       15713 non-null  object
#  21  PESO          16063 non-null  float64
#  22  IDANOMAL      15533 non-null  float64
#  23  DTCADASTRO    16063 non-null  object
#  24  CODANOMAL     126 non-null    object
#  25  NUMEROLOTE    16063 non-null  float64
#  26  VERSAOSIST    16063 non-null  object
#  27  DTRECEBIM     16063 non-null  object
#  28  DIFDATA       16063 non-null  float64
#  29  DTRECORIGA    0 non-null      float64
#  30  NATURALMAE    15905 non-null  float64
#  31  CODMUNNATU    15905 non-null  float64
#  32  CODUFNATU     15905 non-null  float64
#  33  ESCMAE2010    15927 non-null  float64
#  34  SERIESCMAE    7999 non-null   float64
#  35  DTNASCMAE     16045 non-null  float64
#  36  RACACORMAE    15706 non-null  float64
#  37  QTDGESTANT    15339 non-null  float64
#  38  QTDPARTNOR    14969 non-null  float64
#  39  QTDPARTCES    15003 non-null  float64
#  40  IDADEPAI      4903 non-null   float64
#  41  DTULTMENST    10335 non-null  float64
#  42  SEMAGESTAC    15411 non-null  float64
#  43  TPMETESTIM    15411 non-null  float64
#  44  CONSPRENAT    15613 non-null  float64
#  45  MESPRENAT     14616 non-null  float64
#  46  TPAPRESENT    15925 non-null  float64
#  47  STTRABPART    15495 non-null  float64
#  48  STCESPARTO    15620 non-null  float64
#  49  TPNASCASSI    16031 non-null  float64
#  50  TPFUNCRESP    16029 non-null  float64
#  51  TPDOCRESP     16056 non-null  float64
#  52  DTDECLARAC    16037 non-null  float64
#  53  ESCMAEAGR1    15927 non-null  float64
#  54  STDNEPIDEM    16063 non-null  float64
#  55  STDNNOVA      16063 non-null  float64
#  56  CODPAISRES    16063 non-null  float64
#  57  TPROBSON      16063 non-null  float64
#  58  PARIDADE      16063 non-null  float64
#  59  KOTELCHUCK    16063 non-null  float64
#  60  CONTADOR      16063 non-null  float64
#  61  munResStatus  16063 non-null  object
#  62  munResTipo    16063 non-null  object
#  63  munResNome    16063 non-null  object
#  64  munResUf      16063 non-null  object
#  65  munResLat     16062 non-null  float64
#  66  munResLon     16062 non-null  float64
#  67  munResAlt     16062 non-null  float64
#  68  munResArea    16062 non-null  float64
# dtypes: float64(48), int64(6), object(15)
# memory usage: 8.5+ MB

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_raw.groupby(by='munResNome')[['IDADEMAE',
                                     'IDADEPAI']].agg({'IDADEMAE':[('Média','mean')],
                                                       'IDADEPAI':[('Média','mean')]})
# Out:
#                             IDADEMAE   IDADEPAI
#                                Média      Média
# munResNome
# Alta Floresta D'Oeste      25.924901  29.540284
# Alto Alegre dos Parecis    24.967742  29.588235
# Alto Paraíso               24.962441  24.250000
# Alvorada D'Oeste           25.787879  31.333333
# Ariquemes                  25.622461  31.333333
# Buritis                    25.560748  30.516667
# Cabixi                     25.228571  34.666667
# Cacaulândia                25.536232  36.666667
# Cacoal                     26.893473  30.894184
# Campo Novo de Rondônia     24.982301  30.192308
# Candeias do Jamari         25.491329  29.615385
# Castanheiras               26.882353  30.333333
# Cerejeiras                 27.116129  31.241935
# Chupinguaia                25.535354  30.055556
# Colorado do Oeste          27.855769  33.400000
# Corumbiara                 24.542373  31.454545
# Costa Marques              24.894040  31.240000
# Cujubim                    24.584699  32.000000
# Espigão D'Oeste            25.694545  30.753769
# Governador Jorge Teixeira  24.203125  29.800000
# Guajará-Mirim              25.495169  30.800000
# Itapuã do Oeste            26.970149  44.833333
# Jaru                       26.412417  31.684211
# Ji-Paraná                  26.156951  30.715074
# Machadinho D'Oeste         25.576803  30.942857
# Ministro Andreazza         27.907895  34.030303
# Mirante da Serra           25.393617  33.094340
# Monte Negro                25.341317  34.720000
# Município ignorado - RO    24.000000  22.000000
# Nova Brasilândia D'Oeste   26.206107  30.542857
# Nova Mamoré                25.461187  31.866667
# Nova União                 26.720000  29.333333
# Novo Horizonte do Oeste    27.521739  32.439024
# Ouro Preto do Oeste        26.350427  31.222727
# Parecis                    26.434783  32.333333
# Pimenta Bueno              25.251445  29.699324
# Pimenteiras do Oeste       25.739130  35.600000
# Porto Velho                26.285947  32.584848
# Presidente Médici          25.565476  30.200000
# Primavera de Rondônia      27.538462  32.208333
# Rio Crespo                 26.666667  28.000000
# Rolim de Moura             26.812121  30.533040
# Santa Luzia D'Oeste        25.982456  30.320755
# Seringueiras               25.573171  32.263158
# São Felipe D'Oeste         26.324324  31.294118
# São Francisco do Guaporé   25.770115  31.250000
# São Miguel do Guaporé      26.158416  32.278689
# Teixeirópolis              25.888889  31.321429
# Theobroma                  25.562500  30.833333
# Urupá                      26.857143  31.491525
# Vale do Anari              26.295082  32.636364
# Vale do Paraíso            24.800000  30.458333
# Vilhena                    26.501832  34.161290

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_raw.DTNASC = pd.to_datetime(sinasc_raw.DTNASC)
sinasc_raw.DTNASC
# Out:
# 0       2019-02-19
# 1       2019-02-21
# 2       2019-02-25
# 3       2019-03-20
# 4       2019-03-23
#            ...
# 16059   2019-08-06
# 16060   2019-08-09
# 16061   2019-08-23
# 16062   2019-08-23
# 16063   2019-08-25
# Name: DTNASC, Length: 16064, dtype: datetime64[ns]

# %%
sinasc_day = sinasc_raw[(sinasc_raw.DTNASC.dt.day == 26) &
                                (sinasc_raw.DTNASC.dt.month == 1) &
                                (sinasc_raw.DTNASC.dt.year == 2019)]

print('Em 2019, dos {} nascimentos registrados no Estado de Rondônia, {} ocorreram no dia 26 de janeiro.'.format(
    len(sinasc_raw),
    len(sinasc_day)
))


sinasc_day = sinasc_day.groupby(by=['DTNASC',
                                                    'SEXO',
                                                    'ESCMAE'])['PESO'].mean()

sinasc_day = sinasc_day.to_frame().reindex(labels=['1 a 3 anos',
                                                                   '4 a 7 anos',
                                                                   '8 a 11 anos',
                                                                   '12 anos ou mais'],
                                                           level='ESCMAE')

sinasc_day
# Out:
# Em 2019, dos 16064 nascimentos registrados no Estado de Rondônia, 55 ocorreram no dia 26 de janeiro.
#                                              PESO
# DTNASC     SEXO      ESCMAE
# 2019-01-26 Feminino  4 a 7 anos       3003.333333
#                      8 a 11 anos      3337.736842
#                      12 anos ou mais  3208.333333
#            Masculino 4 a 7 anos       3335.250000
#                      8 a 11 anos      3367.941176
#                      12 anos ou mais  3375.000000

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
print('Municípios em que nasceram menos bebês:\n')
print(sinasc_raw.munResNome.value_counts().sort_values().head())

sinasc_raw['COUNT'] = 1
sinasc_3 = sinasc_raw.groupby(by='munResNome')[['COUNT',
                                                'IDADEMAE',
                                                'IDADEPAI']].agg(
    {'COUNT':[('Quantidade de bebês nascidos','count')],
     'IDADEMAE':[('idade média','mean'),
                 ('idade máxima',max),
                 ('idade mínima',min)],
     'IDADEPAI':[('idade média','mean'),
                 ('idade máxima',max),
                 ('idade mínima',min)]})

sinasc_3.sort_values(('COUNT', 'Quantidade de bebês nascidos'))
# Out:
# Municípios em que nasceram menos bebês:
#
# munResNome
# Município ignorado - RO     1
# Castanheiras               17
# Parecis                    23
# Pimenteiras do Oeste       23
# Primavera de Rondônia      26
# Name: count, dtype: int64
#                                                  COUNT    IDADEMAE  \
#                           Quantidade de bebês nascidos idade média
# munResNome
# Município ignorado - RO                              1   24.000000
# Castanheiras                                        17   26.882353
# Pimenteiras do Oeste                                23   25.739130
# Parecis                                             23   26.434783
# Primavera de Rondônia                               26   27.538462
# Cabixi                                              35   25.228571
# Teixeirópolis                                       36   25.888889
# São Felipe D'Oeste                                  37   26.324324
# Vale do Paraíso                                     45   24.800000
# Novo Horizonte do Oeste                             46   27.521739
# Theobroma                                           48   25.562500
# Rio Crespo                                          48   26.666667
# Nova União                                          50   26.720000
# Santa Luzia D'Oeste                                 57   25.982456
# Corumbiara                                          59   24.542373
# Vale do Anari                                       61   26.295082
# Governador Jorge Teixeira                           64   24.203125
# Itapuã do Oeste                                     67   26.970149
# São Francisco do Guaporé            40           14   31.250000         43.0
# Cujubim                             42           14   32.000000         44.0
# São Miguel do Guaporé               42           14   32.278689         60.0
# Alto Paraíso                        42           11   24.250000         29.0
# Nova Mamoré                         42           15   31.866667         43.0
# Alta Floresta D'Oeste               53           14   29.540284         58.0
# Espigão D'Oeste                     43           14   30.753769         86.0
# Machadinho D'Oeste                  43           14   30.942857         53.0
# Buritis                             42           14   30.516667         49.0
# Pimenta Bueno                       42           13   29.699324         70.0
# Ouro Preto do Oeste                 44           14   31.222727         60.0
# Guajará-Mirim                       43           13   30.800000         44.0
# Jaru                                45           12   31.684211         62.0
# Rolim de Moura                      43           14   30.533040         57.0
# Vilhena                             43           14   34.161290         54.0
# Ji-Paraná                           44           13   30.715074         63.0
# Cacoal                              47           14   30.894184         66.0
# Ariquemes                           44           13   31.333333         46.0
# Porto Velho                         47           12   32.584848         65.0
#
#
#                           idade mínima
# munResNome
# Município ignorado - RO           22.0
# Castanheiras                      17.0
# Pimenteiras do Oeste              25.0
# Parecis                           18.0
# Primavera de Rondônia             21.0
# Cabixi                            31.0
# Teixeirópolis                     20.0
# São Felipe D'Oeste                18.0
# Vale do Paraíso                   19.0
# Novo Horizonte do Oeste           22.0
# Theobroma                         25.0
# Rio Crespo                        28.0
# Nova União                        18.0
# Santa Luzia D'Oeste               18.0
# Corumbiara                        25.0
# Vale do Anari                     23.0
# Governador Jorge Teixeira         22.0
# Itapuã do Oeste                   36.0
# Cacaulândia                       28.0
# Ministro Andreazza                21.0
# Seringueiras                      22.0
# Urupá                             19.0
# Alto Alegre dos Parecis           16.0
# Mirante da Serra                  20.0
# Chupinguaia                       20.0
# Alvorada D'Oeste                  17.0
# Colorado do Oeste                 23.0
# Campo Novo de Rondônia            21.0
# Nova Brasilândia D'Oeste          20.0
# Costa Marques                     17.0
# Cerejeiras                        19.0
# Monte Negro                       20.0
# Presidente Médici                 16.0
# Candeias do Jamari                22.0
# São Francisco do Guaporé          19.0
# Cujubim                           21.0
# São Miguel do Guaporé             19.0
# Alto Paraíso                      21.0
# Nova Mamoré                       19.0
# Alta Floresta D'Oeste             17.0
# Espigão D'Oeste                   16.0
# Machadinho D'Oeste                17.0
# Buritis                           18.0
# Pimenta Bueno                     17.0
# Ouro Preto do Oeste               18.0
# Guajará-Mirim                     20.0
# Jaru                              19.0
# Rolim de Moura                    16.0
# Vilhena                           20.0
# Ji-Paraná                         15.0
# Cacoal                            17.0
# Ariquemes                         20.0
# Porto Velho                       17.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_mar = sinasc_raw[sinasc_raw.DTNASC.dt.month == 3].copy()

print('O município que mais nasceu bebê no mês de março foi {} com {} nascimentos.'.format(
    sinasc_mar['munResNome'].value_counts().index[0],
    sinasc_mar['munResNome'].value_counts().values[0]))

sinasc_mar['MES'] = sinasc_mar['DTNASC'].dt.month_name()
sinasc_mar['COUNT'] = 1
sinasc_4 = sinasc_mar.groupby(by=['MES',
                                  'munResNome']
                             )[['COUNT',
                                'QTDFILVIVO',
                                'IDADEMAE',
                                'IDADEPAI']
                              ].agg({'COUNT':[('Qtd de bebês nascidos','count')],
                                     'QTDFILVIVO':[('Média','mean'),
                                                   ('Máx',max),
                                                   ('Mín',min)],
                                     'IDADEMAE':[('Média','mean'),
                                                 ('Máx',max),
                                                 ('Mín',min),
                                                 ('Amplitude',lambda x: x.max()-x.min())],
                                     'IDADEPAI':[('Média','mean'),
                                                 ('Máx',max),
                                                 ('Mín',min),
                                                 ('Amplitude',lambda x: x.max()-x.min())]
                                    })

sinasc_4['Diferença da média IDADEPAI-IDADEMAE'] = sinasc_4[('IDADEPAI','Média')]-sinasc_4[('IDADEMAE','Média')]
sinasc_4.sort_values(('COUNT', 'Qtd de bebês nascidos'),
                     ascending=False
                    )
# Out:
# O município que mais nasceu bebê no mês de março foi Porto Velho com 744 nascimentos.
#                                                 COUNT QTDFILVIVO            \
#                                 Qtd de bebês nascidos      Média  Máx  Mín
# MES   munResNome
# March Porto Velho                                 744   1.295056  9.0  0.0
#       Ji-Paraná                                   188   0.828877  4.0  0.0
#       Vilhena                                     148   0.979592  5.0  0.0
#       Ariquemes                                   141   1.064748  4.0  0.0
#       Cacoal                                      133   0.969697  7.0  0.0
#       Jaru                                         80   1.025641  5.0  0.0
#       Guajará-Mirim                                75   1.534247  8.0  0.0
#       Rolim de Moura                               69   0.724638  5.0  0.0
#       Ouro Preto do Oeste                          67   1.014925  5.0  0.0
#       Pimenta Bueno                                62   0.836066  4.0  0.0
#       Buritis                                      59   1.421053  4.0  0.0
#       Nova Mamoré                                  53   1.360000  6.0  0.0
#       Espigão D'Oeste                              44   1.386364  6.0  0.0
#       Machadinho D'Oeste                           44   1.000000  6.0  0.0
#       São Miguel do Guaporé                        41   1.000000  4.0  0.0
#       Candeias do Jamari                           33   1.250000  4.0  0.0
#       São Francisco do Guaporé                     31   1.161290  6.0  0.0
#       Alta Floresta D'Oeste                        31   0.903226  4.0  0.0
#       Presidente Médici                            29   0.724138  3.0  0.0
#       Costa Marques                                24   1.208333  4.0  0.0
#       Alvorada D'Oeste                             22   1.000000  3.0  0.0
#       Alto Paraíso                                 22   1.285714  3.0  0.0
#       Monte Negro                                  20   0.700000  3.0  0.0
#       Nova Brasilândia D'Oeste                     20   0.947368  3.0  0.0
#       Colorado do Oeste                            19   1.000000  4.0  0.0
#       Seringueiras                                 19   1.000000  2.0  0.0
#       Chupinguaia                                  18   1.055556  4.0  0.0
#       Cujubim                                      17   1.294118  5.0  0.0
#       Cerejeiras                                   16   0.875000  2.0  0.0
#       Urupá                                        14   0.928571  2.0  0.0
#       Vale do Paraíso                              13   0.583333  2.0  0.0
#       Campo Novo de Rondônia                       13   1.285714  2.0  0.0
#       Corumbiara                                   12   0.909091  3.0  0.0
#       Vale do Anari                                11   0.818182  2.0  0.0
#       Alto Alegre dos Parecis                      10   0.888889  2.0  0.0
#       Governador Jorge Teixeira                    10   0.555556  2.0  0.0
#       Cacaulândia                                  10   1.200000  4.0  0.0
#       Rio Crespo                                    9   1.000000  3.0  0.0
#       Mirante da Serra                              9   1.000000  2.0  0.0
#       Governador Jorge Teixeira  24.500000  33  16        17        NaN   NaN
#       Cacaulândia                26.200000  32  18        14        NaN   NaN
#       Rio Crespo                 28.888889  37  20        17        NaN   NaN
#       Mirante da Serra           24.888889  37  16        21  31.000000  32.0
#       Theobroma                  26.875000  35  20        15  28.500000  31.0
#       Itapuã do Oeste            25.625000  39  17        22  39.000000  39.0
#       Santa Luzia D'Oeste        23.285714  27  18         9  27.142857  37.0
#       Nova União                 23.428571  38  16        22  27.333333  29.0
#       Cabixi                     28.000000  36  17        19        NaN   NaN
#       Parecis                    28.000000  37  20        17  30.000000  40.0
#       Ministro Andreazza         27.166667  35  19        16  38.000000  47.0
#       Pimenteiras do Oeste       23.000000  29  19        10        NaN   NaN
#       Primavera de Rondônia      26.800000  33  22        11  32.750000  35.0
#       São Felipe D'Oeste         23.600000  31  19        12  29.250000  32.0
#       Novo Horizonte do Oeste    29.000000  37  19        18  30.400000  36.0
#       Castanheiras               30.500000  35  27         8  36.000000  42.0
#       Teixeirópolis              26.666667  32  21        11  27.000000  32.0
#
#                                                  \
#                                   Mín Amplitude
# MES   munResNome
# March Porto Velho                19.0      43.0
#       Ji-Paraná                  16.0      40.0
#       Vilhena                    27.0      20.0
#       Ariquemes                  28.0       1.0
#       Cacoal                     17.0      30.0
#       Jaru                       21.0      20.0
#       Guajará-Mirim              26.0      17.0
#       Rolim de Moura             19.0      31.0
#       Ouro Preto do Oeste        19.0      38.0
#       Pimenta Bueno              17.0      32.0
#       Buritis                    18.0      30.0
#       Nova Mamoré                19.0      24.0
#       Espigão D'Oeste            19.0      37.0
#       Machadinho D'Oeste         23.0      17.0
#       São Miguel do Guaporé      30.0       9.0
#       Candeias do Jamari         25.0       0.0
#       São Francisco do Guaporé   19.0      21.0
#       Alta Floresta D'Oeste      20.0      25.0
#       Presidente Médici          24.0      36.0
#       Costa Marques              19.0      12.0
#       Alvorada D'Oeste           26.0      16.0
#       Alto Paraíso               23.0       6.0
#       Monte Negro                22.0      33.0
#       Nova Brasilândia D'Oeste   25.0      10.0
#       Colorado do Oeste          27.0      26.0
#       Seringueiras               26.0       8.0
#       Chupinguaia                20.0      17.0
#       Cujubim                    39.0       0.0
#       Cerejeiras                 26.0      14.0
#       Urupá                      22.0      25.0
#       Vale do Paraíso            19.0      27.0
#       Campo Novo de Rondônia     21.0      19.0
#       Corumbiara                 37.0       0.0
#       Vale do Anari              30.0       4.0
#       Alto Alegre dos Parecis    21.0      17.0
#       Governador Jorge Teixeira   NaN       NaN
#       Cacaulândia                 NaN       NaN
#       Rio Crespo                  NaN       NaN
#       Mirante da Serra           30.0       2.0
#       Theobroma                  26.0       5.0
#       Itapuã do Oeste            39.0       0.0
#       Santa Luzia D'Oeste        19.0      18.0
#       Nova União                 26.0       3.0
#       Cabixi                      NaN       NaN
#       Parecis                    24.0      16.0
#       Ministro Andreazza         27.0      20.0
#       Pimenteiras do Oeste        NaN       NaN
#       Primavera de Rondônia      27.0       8.0
#       São Felipe D'Oeste         27.0       5.0
#       Novo Horizonte do Oeste    24.0      12.0
#       Castanheiras               32.0      10.0
#       Teixeirópolis              22.0      10.0
#
#                                 Diferença da média IDADEPAI-IDADEMAE
#
# MES   munResNome
# March Porto Velho                                           8.032258
#       Ji-Paraná                                             5.453919
#       Vilhena                                               7.150338
#       Ariquemes                                             3.361702
#       Cacoal                                                3.542031
#       Jaru                                                  6.950000
#       Guajará-Mirim                                         8.166667
#       Rolim de Moura                                        3.663373
#       Ouro Preto do Oeste                                   4.652612
#       Pimenta Bueno                                         4.433692
#       Buritis                                               6.708605
#       Nova Mamoré                                           7.065180
#       Espigão D'Oeste                                       5.257576
#       Machadinho D'Oeste                                    5.704545
#       São Miguel do Guaporé                                 7.300813
#       Candeias do Jamari                                    0.636364
#       São Francisco do Guaporé                              3.822581
#       Alta Floresta D'Oeste                                 3.931452
#       Presidente Médici                                     7.583744
#       Costa Marques                                        -0.666667
#       Alvorada D'Oeste                                      7.627273
#       Alto Paraíso                                          1.181818
#       Monte Negro                                           9.350000
#       Nova Brasilândia D'Oeste                              3.016667
#       Colorado do Oeste                                    11.013158
#       Seringueiras                                          4.859649
#       Chupinguaia                                           2.722222
#       Cujubim                                              14.117647
#       Cerejeiras                                            4.159722
#       Urupá                                                 3.873626
#       Vale do Paraíso                                       6.384615
#       Campo Novo de Rondônia                                7.221154
#       Corumbiara                                           12.916667
#       Vale do Anari                                         7.454545
#       Alto Alegre dos Parecis                               4.122222
#       Governador Jorge Teixeira                                  NaN
#       Cacaulândia                                                NaN
#       Rio Crespo                                                 NaN
#       Mirante da Serra                                      6.111111
#       Theobroma                                             1.625000
#       Itapuã do Oeste                                      13.375000
#       Santa Luzia D'Oeste                                   3.857143
#       Nova União                                            3.904762
#       Cabixi                                                     NaN
#       Parecis                                               2.000000
#       Ministro Andreazza                                   10.833333
#       Pimenteiras do Oeste                                       NaN
#       Primavera de Rondônia                                 5.950000
#       São Felipe D'Oeste                                    5.650000
#       Novo Horizonte do Oeste                               1.400000
#       Castanheiras                                          5.500000
#       Teixeirópolis                                         0.333333

# %%
print('Mediana de todos os municípios no mês de março:')
round(sinasc_4.groupby(by='MES').median())
# Out:
# Mediana de todos os municípios no mês de março:
#                       COUNT QTDFILVIVO           IDADEMAE              \
#       Qtd de bebês nascidos      Média  Máx  Mín    Média   Máx   Mín
# MES
# March                  18.0        1.0  3.0  0.0     26.0  37.0  16.0
#
#                 IDADEPAI                        \
#       Amplitude    Média   Máx   Mín Amplitude
# MES
# March      21.0     31.0  40.0  24.0      17.0
#
#       Diferença da média IDADEPAI-IDADEMAE
#
# MES
# March                                  5.0

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.
#
# Com base nos resultados apresentados, podemos observar que:
#
# - A média de filhos vivos se mantém em torno de 1, independentemente da quantidade de bebês nascidos, em todos os municípios do estado.
# - A média de idade dos pais é geralmente maior do que a das mães na maioria dos municípios.
# - Embora o município de Ariquemes seja um dos cinco com maior número de bebês nascidos, com um total de 141 nascimentos, a variação de idade entre os pais é uma das menores, com uma diferença de apenas 1 ano, de 28 a 29 anos.
